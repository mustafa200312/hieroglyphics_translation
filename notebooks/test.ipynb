# %%
import pandas as pd
import torch

# %%
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)} is available.")
else:
    print("No GPU available. Training will run on CPU.")
# Out:
# GPU: NVIDIA GeForce RTX 3060 Laptop GPU is available.

# %%
df = pd.read_csv("../Cleaned_Data/bbaw_egyptian_w_hieroglyphs.csv")

# %%
df.head()
# Out:
#                                        transcription  \
# 0  jr,j-pꜥ,t ḥꜣ,tj-ꜥ ḫtm,w-bj,tj smr-wꜥ,tj jm,j-r...
# 1  j ꜥnḫ.w.pl tp,j.pl-tꜣ swꜣ.t =sn ḥr jz pn m-ḫdi...
# 2  jnk mḥ-jb-n-nswt m ḥw,t-nṯr rʾ-Nḫn m pr Stj,t ...
# 3  ꜥq jb.pl ḥr-sꜣ mr,yt jm,j-rʾ-ꜥḥꜥ,w-wr-m-pr-nsw...
# 4  jw jri̯.n = jz m ḥz,t nswt sjqr.n wj ḥm =f m t...
#
#                                          translation  \
# 0  Hereditary noble and prince, royal seal-bearer...
# 1  O living ones, who are upon the earth, who sha...
# 2  I was a trusted one of the king in the temple,...
# 3  A trusted one upon the landing place, great ov...
# 4  I built a tomb through the favour of the king,...
#
#                                          hieroglyphs
# 0  D21 Q3 D36 F4 D36 L2 X1 S19 S29 U23 T21 X1 G17...
# 1  M17 A26 S34 Aa1 G43 A1 Z3 h N17 N23 A1 Z2B S29...
# 2  W24 V31 V22 F34 N35 M23 X1 N35 G17 R8 O6 X1 O1...
# 3  G35 F34 F34 F34 D2 Z1 Aa17 U6 D21 M17 M17 X1 N...
# 4  M17 G43 D4 N35 M17 M40 O34 O1 Z1 G17 V28 W14 X...

# %%
# we have 2 columns transcription and hieroglyphs we want to calc number of n grams for each
df['translation_len'] = df['transcription'].apply(lambda x: len(x.split()))
df['hieroglyphs_len'] = df['hieroglyphs'].apply(lambda x:len(x.split()))
